# %% [markdown]
# # 11. Container With Most Water
#
# You are given an integer array height of length n. There are n vertical lines drawn such that the two endpoints of the ith line are (i, 0) and (i, height[i]).
#
# Find two lines that together with the x-axis form a container, such that the container contains the most water.
#
# Return the maximum amount of water a container can store.
#
# Notice that you may not slant the container.
#
# ## Example 1:
#
# ![image.png](attachment:image.png)
#
# Input: height = [1,8,6,2,5,4,8,3,7]
# Output: 49
# Explanation: The above vertical lines are represented by array [1,8,6,2,5,4,8,3,7]. In this case, the max area of water (blue section) the container can contain is 49.
#
# Example 2:
#
# Input: height = [1,1]
# Output: 1

# %% [markdown]
# # Specification
#
# O problema envolve em retornar a area axis-x X axis-Y do container com a maior area possivel
#
# A Altura é 7 pois min(7,8) = 7
# A Largura é o width = right - left
#
# resultando em 49
#
# height = [1,8,6,2,5,4,8,3,7]
#
# ## Plan
#
# A solução mais simples bruta, seria fazer dois loops for i for j calculando a area atraves, usando a area = min(height[left], height[right]) * (right - left) e max_area = max(max_area,area) dando N^2
#
# [1,8,6,2,5,4,8,3,7] Começamos com a width maximo no começo
#  L               R
#
# Quando vamos fechando a largura, diminuindo, buscamos achamos uma alturas grandes suficiente para suprir a diminuição da largura
#
# como a barra 1 é pequena movemos L para a direta
#
# [1,8,6,2,5,4,8,3,7]
#    L             R
#
# if height[left] > height[right] right -= 1
#
# [1,8,6,2,5,4,8,3,7]
#    L      ...  R
#
# [1,8,6,2,5,4,8,3,7]
#    L      ...R
#
# if height[left] <= height[right]: left+=1
#
# [1,8,6,2,5,4,8,3,7]
#      L       R
#
# [1,8,6,2,5,4,8,3,7]
#              R
#              L
#
# Parou pois L encontrou R

# %%
from  typing  import List
class Solution:
    def maxArea(self, height: List[int]) -> int:
        max_area = 0
        left,right = 0, len(height) - 1
        def calculate_area(left:int, right:int) -> int:
            width = right - left
            return min(height[left], height[right]) * width
        while left < right:
            area = calculate_area(left,right)
            max_area = max(max_area,area)
            if height[left] <= height[right]:
                left += 1
            else:
                right -= 1
        return max_area
