# %% [markdown]
# ```markdown
# # 🚗 Service Lane – HackerRank Problem
#
# A driver is traveling on the freeway when the **check engine** light turns on. The driver wants to get service immediately. Fortunately, a **service lane** runs parallel to the highway — but its **width varies** along the route.
#
# Your task is to determine the **maximum vehicle width** that can pass safely for a given segment of this service lane.
#
# ![alt text](image-2.png)
#
# ---
#
# ## 🛣️ Problem Description
#
# You are given:
#
# - An array `width[]` where each element represents the **width** of the service lane at that point.
# - A list of test cases, where each test case gives:
#   - **Entry index**
#   - **Exit index**
#
# For each test case, find the **minimum width** in that subarray.
# This minimum determines the **maximum vehicle size** that can pass through.
#
# ---
#
# ## 🧠 Example
#
# Given:
#
# ```
#
# width = [2, 3, 1, 2, 3, 2, 3, 3]
#
# ````
#
# If:
#
# - Entry = `0`, Exit = `3` → segment widths: `[2, 3, 1, 2]` → max vehicle size = **1**
# - Entry = `4`, Exit = `6` → `[3, 2, 3]` → max vehicle size = **2**
#
# ---
#
# ## 📌 Function Description
#
# Implement the function:
#
# ```python
# def serviceLane(n, cases, width):
#     # return a list of minimum widths for each case
# ````
#
# ### Parameters
#
# | Parameter | Type              | Description                                            |
# | --------- | ----------------- | ------------------------------------------------------ |
# | `n`       | `int`             | Number of width measurements                           |
# | `cases`   | `List[List[int]]` | Each pair represents start and end indices (inclusive) |
# | `width`   | `List[int]`       | Widths along the service lane                          |
#
# ### Returns
#
# * `List[int]`: the **maximum width vehicle** that can pass for each segment
#
# ---
#
# ## 📥 Input Format
#
# ```
# n t
# w1 w2 w3 ... wn
# case1_start case1_end
# case2_start case2_end
# ...
# ```
#
# ---
#
# ## ✔️ Constraints
#
# * Each segment is inclusive
# * Vehicle width = **minimum width** in that range
#
# ---
#
# ## 🧪 Sample Input
#
# ```
# 8 5
# 2 3 1 2 3 2 3 3
# 0 3
# 4 6
# 6 7
# 3 5
# 0 7
# ```
#
# ## 📤 Sample Output
#
# ```
# 1
# 2
# 3
# 2
# 1
# ```
#
# ---
#
# ## 📘 Explanation
#
# Visual representation:
#
# ```
# Index: Width
# 0:     2
# 1:     3
# 2:     1
# 3:     2
# 4:     3
# 5:     2
# 6:     3
# 7:     3
# ```
#
# Test case evaluation:
#
# 1. **0 → 3** → widths: `[2, 3, 1, 2]` → min = **1**
# 2. **4 → 6** → `[3, 2, 3]` → min = **2**
# 3. **6 → 7** → `[3, 3]` → min = **3**
# 4. **3 → 5** → `[2, 3, 2]` → min = **2**
# 5. **0 → 7** → entire list → min = **1**
#
# ---
#
# ## 💡 Tip
#
# This is a simple **range minimum query** problem.
# Since ranges are small, a direct min() per test case is efficient.
#
# ---
#
# ```markdown
#
# ---
#
# If you'd like, I can also generate:
#
# ✅ A code cell with the solution
# ✅ A Jupyter-optimized visualization of the lane
# ✅ A version with input widgets so you can interactively test segments
#
# Just tell me!
# ```

# %%
import math
import os
import random
import re
import sys

#
# Complete the 'serviceLane' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER n
#  2. 2D_INTEGER_ARRAY cases
#

def serviceLane(n, width, cases):
    result = []
    for start, end in cases:
        result.append(min(width[start:end+1]))
    return result

width = [1, 2, 2, 2, 1]

n = len(width)
cases = [
    [2, 3],
    [1, 4],
    [2, 4],
    [2, 4],
    [2, 3],
]

print(serviceLane(n,width, cases))
# Out:
# [2, 1, 1, 1, 2]
