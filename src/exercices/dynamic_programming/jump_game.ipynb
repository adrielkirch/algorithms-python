# %% [markdown]
# ## 55. Jump Game
#
# You are given an integer array nums. You are initially positioned at the array's first index, and each element in the array represents your maximum jump length at that position.
#
# Return true if you can reach the last index, or false otherwise.
# s
#
# Example 1:
#
# Input: nums = [2,3,1,1,4]
# Output: true
# Explanation: Jump 1 step from index 0 to 1, then 3 steps to the last index.
#
# Example 2:
#
# Input: nums = [3,2,1,0,4]
# Output: false
# Explanation: You will always arrive at index 3 no matter what. Its maximum jump length is 0, which makes it impossible to reach the last index.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def canJump(nums):
    """Greedy (alcance máximo). Retorna True se for possível alcançar o último índice."""
    max_reach = 0
    n = len(nums)
    for i in range(n):
        if i > max_reach:
            return False
        max_reach = max(max_reach, nums[i] + i)
    return True

# Exemplos de teste
nums1 = [3,2,1,0,4]
print(nums1, '->', canJump(nums1))  # False
nums2 = [2,3,1,1,4]
print(nums2, '->', canJump(nums2))  # True
# Out:
# False
# True

# %% [markdown]
# ### Solução com Programação Dinâmica (DP)
#
# Nesta abordagem, criamos um array `dp` onde `dp[i]` indica se é possível chegar ao índice `i` a partir do início. Inicialmente, apenas `dp[0]` é verdadeiro. Para cada posição, verificamos se conseguimos chegar nela a partir de alguma posição anterior.

# %%
def canJumpDP(nums):
    n = len(nums)
    dp = [False] * n
    dp[0] = True
    for i in range(1, n):
        for j in range(i):
            if dp[j] and j + nums[j] >= i:
                dp[i] = True
                break
    return dp[-1]

# Exemplos de teste
nums1 = [3,2,1,0,4]
print(canJumpDP(nums1))  # False
nums2 = [2,3,1,1,4]
print(canJumpDP(nums2))  # True
