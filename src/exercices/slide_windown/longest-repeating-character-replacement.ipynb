# %% [markdown]
# # 424. Longest Repeating Character Replacement
#
# You are given a string s and an integer k. You can choose any character of the string and change it to any other uppercase English character. You can perform this operation at most k times.
#
# Return the length of the longest substring containing the same letter you can get after performing the above operations.
#
# Example 1:
#
# Input: s = "ABAB", k = 2
# Output: 4
# Explanation: Replace the two 'A's with two 'B's or vice versa.
# Example 2:
#
# Input: s = "AABABBA", k = 1
# Output: 4
# Explanation: Replace the one 'A' in the middle with 'B' and form "AABBBBA".
# The substring "BBBB" has the longest repeating letters, which is 4.
# There may exists other ways to achieve this answer too.

# %% [markdown]
# "A A B A B B A"

# %%
class Solution:
    def characterReplacement(self, s: str, k: int) -> int:
        longest = left = 0
        counts = [0]*26

        for right in range(len(s)):
            counts[ord(s[right]) - ord('A')] += 1

            while (right - left + 1) - max(counts) > k:
                counts[ord(s[left]) - ord('A')] -= 1
                left += 1
            longest = max(longest, right - left + 1)
            
        return longest
sol = Solution()
print(sol.characterReplacement("ABAB", 2))        # 4
print(sol.characterReplacement("AABABBA", 1))     # 4
print(sol.characterReplacement("AAAA", 2))        # 4
print(sol.characterReplacement("ABCDE", 1))       # 2
print(sol.characterReplacement("BAAAAB", 2))      # 6
print(sol.characterReplacement("AABACCA", 2))     # 5
print(sol.characterReplacement("ABBBCCDAA", 2))   # 5
# Out:
# 4
# 4
# 4
# 2
# 6
# 5
# 5

# %%
sol = Solution()
print(sol.characterReplacement("ABAB", 2))        # 4
print(sol.characterReplacement("AABABBA", 1))     # 4
print(sol.characterReplacement("AAAA", 2))        # 4
print(sol.characterReplacement("ABCDE", 1))       # 2
print(sol.characterReplacement("BAAAAB", 2))      # 6
print(sol.characterReplacement("AABACCA", 2))     # 5
print(sol.characterReplacement("ABBBCCDAA", 2))   # 5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 sol = Solution()
# ----> 2 print(sol.characterReplacement("ABAB", 2))        # 4
#       3 print(sol.characterReplacement("AABABBA", 1))     # 4
#       4 print(sol.characterReplacement("AAAA", 2))        # 4
#
# Cell In[8], line 7, in Solution.characterReplacement(self, s, k)
#       4 counts = [0]*26
#       6 for right in range(len(s)):
# ----> 7     counts[ord(s[right]) - ord('a')] += 1
#       9     while (right - left + 1) - max(counts) > k:
#      10         counts[ord(s[left]) - ord('a')] -= 1
#
# IndexError: list index out of range
