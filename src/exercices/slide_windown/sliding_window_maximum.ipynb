# %% [markdown]
# # Sliding Window Maximum
#
# Diferencial forte: introduz monotonic queue (deque).
#
# - Muda totalmente o nível.
# - Aparece bastante em Big Tech.
#
# (Exercício vazio para implementação)
