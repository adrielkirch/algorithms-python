# %% [markdown]
# ## 3. Longest Substring Without Repeating Characters
#
# Given a string s, find the length of the longest substring without duplicate characters.
#
#
# ### Example 1:
#
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3. Note that "bca" and "cab" are also correct answers.
#
# ### Example 2:
#
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
#
# ###  Example 3:
#
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.

# %% [markdown]
# s = "a b c a b c b b"
#       0 1 2 3 4 5 6 7
#
# L=0, R=0
# a b c a b c b b
# L
# R
# set{} | max_len=0
#
# L=0, R=0
# 'a' não está no set → adiciona 'a'
# set{a} | max_len=1
#
# L=0, R=1
# a b c a b c b b
# L R
# 'b' não está no set → adiciona 'b'
# set{a, b} | max_len=2
#
# L=0, R=2
# a b c a b c b b
# L   R
# 'c' não está no set → adiciona 'c'
# set{a, b, c} | max_len=3
#
# L=0, R=3
# a b c a b c b b
# L     R
# 'a' já está no set → remove 'a' do set, L+=1 (L=1)
# set{b, c}
# 'a' não está no set → adiciona 'a'
# set{a, b, c} | max_len=3
#
# L=1, R=3
# a b c a b c b b
#   L   R
#
# L=1, R=4
# a b c a b c b b
#   L     R
# 'b' já está no set → remove 'b' do set, L+=1 (L=2)
# set{a, c}
# 'b' não está no set → adiciona 'b'
# set{a, b, c} | max_len=3
#
# L=2, R=4
# a b c a b c b b
#     L   R
#
# L=2, R=5
# a b c a b c b b
#     L     R
# 'c' já está no set → remove 'c' do set, L+=1 (L=3)
# set{a, b}
# 'c' não está no set → adiciona 'c'
# set{a, b, c} | max_len=3
#
# L=3, R=5
# a b c a b c b b
#       L   R
#
# L=3, R=6
# a b c a b c b b
#       L     R
# 'b' já está no set → remove 'a' do set, L+=1 (L=4)
# set{b, c}
# 'b' já está no set → remove 'b' do set, L+=1 (L=5)
# set{c}
# 'b' não está no set → adiciona 'b'
# set{b, c} | max_len=3
#
# L=5, R=6
# a b c a b c b b
#           L R
#
# L=5, R=7
# a b c a b c b b
#           L   R
# 'b' já está no set → remove 'c' do set, L+=1 (L=6)
# set{b}
# 'b' já está no set → remove 'b' do set, L+=1 (L=7)
# set{}
# 'b' não está no set → adiciona 'b'
# set{b} | max_len=3
#
# L=7, R=7
# a b c a b c b b
#               L
#               R
#
# Fim. Nossomaior é 3

# %%
class Solution(object):
    def lengthOfLongestSubstring(self, s):
        if not s:
            return 0

        seen = set()
        left = 0    
        max_length = 0
        total_caracters = len(s) 

        for right in range(total_caracters):
            while s[right] in seen:
                print(f"🔁 '{s[right]}' repetido → removendo '{s[left]}' do conjunto")
                seen.remove(s[left])
                left += 1

            seen.add(s[right])
            max_length = max(max_length, len(seen))
            
        return max_length


# 🧪 Testes
print(Solution().lengthOfLongestSubstring("abcabcbb"))  # 3
print(Solution().lengthOfLongestSubstring("bbbbb"))     # 1
print(Solution().lengthOfLongestSubstring("pwwkew"))    # 3
# Out:
# ✅ Janela atual: 'a' | Conjunto: {'a'} | max_len=1
# ✅ Janela atual: 'ab' | Conjunto: {'b', 'a'} | max_len=2
# ✅ Janela atual: 'abc' | Conjunto: {'b', 'c', 'a'} | max_len=3
# 🔁 'a' repetido → removendo 'a' do conjunto
# ✅ Janela atual: 'bca' | Conjunto: {'b', 'c', 'a'} | max_len=3
# 🔁 'b' repetido → removendo 'b' do conjunto
# ✅ Janela atual: 'cab' | Conjunto: {'b', 'c', 'a'} | max_len=3
# 🔁 'c' repetido → removendo 'c' do conjunto
# ✅ Janela atual: 'abc' | Conjunto: {'b', 'c', 'a'} | max_len=3
# 🔁 'b' repetido → removendo 'a' do conjunto
# 🔁 'b' repetido → removendo 'b' do conjunto
# ✅ Janela atual: 'cb' | Conjunto: {'b', 'c'} | max_len=3
# 🔁 'b' repetido → removendo 'c' do conjunto
# 🔁 'b' repetido → removendo 'b' do conjunto
# ✅ Janela atual: 'b' | Conjunto: {'b'} | max_len=3
# 3
# ✅ Janela atual: 'b' | Conjunto: {'b'} | max_len=1
# 🔁 'b' repetido → removendo 'b' do conjunto
# ✅ Janela atual: 'b' | Conjunto: {'b'} | max_len=1
# 🔁 'b' repetido → removendo 'b' do conjunto
# ...
