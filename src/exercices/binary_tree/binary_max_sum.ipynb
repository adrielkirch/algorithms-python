# %% [markdown]
# # Binary Tree Maximum Path Sum
# Given a binary tree, find the maximum path sum. A path is any sequence of nodes from some starting node to any node in the tree along the parent-child connections. The path must contain at least one node and does not need to go through the root.
#
# **Example:**
# - Input: [1,2,3]
# - Output: 6
# - Explanation: The path 2 → 1 → 3 yields the maximum sum.
#
# **Constraints:**
# - The number of nodes in the tree is in the range [1, 2000].
# - $-1000 \leq \text{Node.val} \leq 1000$
#
# **Goal:**
# Implement a function that, given the root of a binary tree, returns the maximum sum of any path.

# %%
from typing import List, Optional
from collections import deque
class Node:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


class Solution:
    def maxBinaryPathSum(self, root: Optional[Node]) -> int:
        if root is None:
            return 0
        max_sum = float('-inf')
        stack = [(root, root.val)]
        while stack:
            node, curr_sum = stack.pop()
            if node.left is None and node.right is None:
                max_sum = max(max_sum, curr_sum)
            if node.left:
                stack.append((node.left, curr_sum + node.left.val))
            if node.right:
                stack.append((node.right, curr_sum + node.right.val))
        return max_sum

# %%
from typing import Optional
class Node:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def maxPathSum(self, root: Optional[Node]) -> int:
        self.max_sum = float('-inf')
        def dfs(node):
            if not node:
                return 0
            left = max(dfs(node.left), 0)
            right = max(dfs(node.right), 0)
            current_sum = node.val + left + right
            self.max_sum = max(self.max_sum, current_sum)
            return node.val + max(left, right)
        dfs(root)
        return self.max_sum

# %%
# Client code: build tree and test maxPathSum
def build_example_tree():
    # Example:
    #      1
    #     / \
    #    2   3
    return Node(1, Node(2), Node(3))

root = build_example_tree()
sol = Solution()
result = sol.maxPathSum(root)
print("Maximum path sum:", result)
