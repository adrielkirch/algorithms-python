# %% [markdown]
# # 🧩 Hackerrank in a String
#
# We say that a string contains the word **hackerrank** if a **subsequence** of its characters spells the word in the correct order.
#
# A **subsequence** means that the characters must appear **in the same order**, but they **do not** need to be contiguous.
#
# ---
#
# ## 📘 Formal Definition
#
# Let the characters **h, a, c, k, e, r, r, a, n, k** appear in string `s` at indices
# `i₁ < i₂ < i₃ < ... < i₁₀`.
#
# If such indices exist, then `s` **contains "hackerrank"** as a subsequence.
#
# ---
#
# ## 📤 Output Requirement
#
# For each query string:
#
# - Print **YES** → if it contains **hackerrank** as a subsequence
# - Print **NO** → otherwise
#
# ---
#
# ## 📝 Function Description
#
# ### `hackerrankInString(s)`
#
# **Parameters:**
# - `string s`: input string
#
# **Returns:**
# - `"YES"` or `"NO"`
#
# ---
#
# ## 📥 Input Format
#
# - The first line contains an integer `q`: number of queries
# - Each of the next `q` lines contains a single query string `s`
#
# ---
#
# ## ⚙️ Constraints
#
# (No special constraints provided.)
#
# ---
#
# ## 📌 Examples
#
# ### **Sample Input 0**
#
# 2
# hereiamstackerrank
# hackerworld
#
# ### **Sample Output 0**
# YES
# NO
#
# - In `hereiamstackerrank`, all characters of **hackerrank** appear in order → **YES**
# - In `hackerworld`, the last three letters `"ank"` are missing → **NO**

# %%
def hackerrankInString(s):
    i = j = 0
    target = 'hackerrank'
    
    while i < len(s):
        if s[i] == target[j]:
            j += 1
        if len(target) == j:
            return 'YES'
        i += 1
    return 'NO'        

print(hackerrankInString('hhaacckkekraraannk'))
print(hackerrankInString('rhbaasdndfsdskgbfefdbrsdfhuyatrjtcrtyytktjjt'))
# Out:
# YES
# NO
