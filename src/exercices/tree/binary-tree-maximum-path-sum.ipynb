# %% [markdown]
# # 24. Binary Tree Maximum Path Sum
#
# A path in a binary tree is a sequence of nodes where each pair of adjacent nodes in the sequence has an edge connecting them. A node can only appear in the sequence at most once. Note that the path does not need to pass through the root.
#
# The path sum of a path is the sum of the node's values in the path.
#
# Given the root of a binary tree, return the maximum path sum of any non-empty path.
#
#
# Example 1:
#
# ![image-2.png](attachment:image-2.png)
#
# Input: root = [1,2,3]
# Output: 6
# Explanation: The optimal path is 2 -> 1 -> 3 with a path sum of 2 + 1 + 3 = 6.
# Example 2:
#
# ![image.png](attachment:image.png)
#
# Input: root = [-10,9,20,null,null,15,7]
# Output: 42
# Explanation: The optimal path is 15 -> 20 -> 7 with a path sum of 15 + 20 + 7 = 42.
#
#
# Constraints:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from typing import Optional

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    max_global = float('-inf')
    def maxPathSum(self, root: Optional[TreeNode]) -> int:
    
        
        def dfs(node):
            if not node:
                return 0
            
            # 1. Mergulha nos filhos. 
            # Se o ganho for negativo, usamos 0 (ignoramos o ramo)
            left_gain = max(dfs(node.left), 0)
            right_gain = max(dfs(node.right), 0)
            
            # 2. Preço do "Pico": 
            # Verificamos a soma se este nó for o ponto de virada do caminho
            current_path_sum = node.val + left_gain + right_gain
            
            # 3. Atualizamos o recorde mundial
            self.max_global = max(self.max_global, current_path_sum)
            
            # 4. Retorno para o PAI:
            # O pai só pode continuar o caminho por UM dos lados
            return node.val + max(left_gain, right_gain)
        
        dfs(root)
        return self.max_global
