# %% [markdown]
# ## 20. Valid Parentheses
#
# Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
#
# An input string is valid if:
#
# Open brackets must be closed by the same type of brackets.
# Open brackets must be closed in the correct order.
# Every close bracket has a corresponding open bracket of the same type.
#
#
# ### Example 1:
#
#     Input: s = "()"
#
#     Output: true
#
# ### Example 2:
#
#     Input: s = "()[]{}"
#
#     Output: true
#
# ### Example 3:
#
#     Input: s = "(]"
#
#     Output: false
#
# ### Example 4:
#
#     Input: s = "([])"
#
#     Output: true
#
# ### Example 5:
#
#     Input: s = "([)]"
#
#     Output: false

# %% [markdown]
# ![Untitled-2026-05-02-2150.png](attachment:Untitled-2026-05-02-2150.png)

# %%
## Heuristics

"""
  [{}]

step i = 0

stack = ['[']

---

step i = 1

char = '{'

stack = ['[','{']

---

step i = 2

char = '}'

stack = ['[','{']

poped =   '{'

---

step i = 3

char = ']'

stack = ['[']


poped =   ']'

------

[]

"""

class Solution(object):
    def isValid(self, s):
        stack = []
        mapping = {')': '(', '}': '{', ']': '['}

        for char in s:
            if char in mapping:
                if not stack:
                    return False
                top = stack.pop()
                if mapping[char] != top:
                    return False
            else:
                stack.append(char)

        return len(stack) == 0

# %% [markdown]
# ---
#
# ## 4️⃣ #Complexity (Veredito Final)
#
# - **Time Complexity:** O(N), pois cada caractere é processado uma única vez (push/pop são O(1)).
# - **Space Complexity:** O(N) no pior caso (todas aberturas, nenhuma fechada → pilha cresce até N).
#
# ---
#
# **Resumo Mentor:**
# - Pilha é a estrutura ideal para problemas de "matching" aninhado.
# - O segredo é sempre comparar o fechamento com o topo da pilha.
# - Retorne False no primeiro erro; só retorne True se a pilha estiver vazia ao final.
#
# Pronto para entrevistas e sistemas de produção!

# %% [markdown]
# ```python
# class Solution:
#     def isValid(self, s: str) -> bool:
#         stack = []  # Pilha para rastrear aberturas
#         mapping = {')': '(', '}': '{', ']': '['}  # Fechamento → abertura
#         for char in s:
#             if char in mapping:
#                 if not stack or stack[-1] != mapping[char]:
#                     return False  # Fechamento sem correspondente
#                 stack.pop()  # Fechamento válido, desempilha
#             else:
#                 stack.append(char)  # Abertura, empilha
#         return not stack  # True se pilha vazia (tudo fechado)
# ```
#
# - Usamos uma pilha porque ela modela perfeitamente o "último aberto, primeiro fechado" (LIFO).
# - O dicionário `mapping` permite checar rapidamente se o fechamento bate com o topo da pilha.
# - Retornamos False imediatamente ao encontrar qualquer inconsistência.
# - No final, se a pilha não está vazia, há aberturas sem fechamento.

# %%
sol = Solution()
print(sol.isValid("()"))       # True
print(sol.isValid("()[]{}"))   # True
print(sol.isValid("(]"))       # False
print(sol.isValid("([])"))     # True
print(sol.isValid("([)]"))     # False
# Out:
# True
# True
# False
# True
# False
