# %% [markdown]
# **Exercise:** Given a n of the basis of a trinagule you need to print the trinagule lookalike:
#
# n = 5
#
# *
# **
# ***
# ****
# *****

# %%
def staircase(n):
    lines = []
    for i in range(1,n+1):
        lines.append('*'*i)
    return '\n'.join(lines)

print(staircase(5))
# Out:
# *
# **
# ***
# ****
# *****
